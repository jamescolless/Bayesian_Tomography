# %%
import pickle
import numpy as np
GS_Single_Qubit_data=pickle.load(open("GS_Single_Qubit_data","r"))

np.save("GS_data", GS_data)
np.save("EE_data", EE_data)
np.save("GS_Single_Qubit_data", GS_Single_Qubit_data)

# %%
print GS_Single_Qubit_data["Measurements"]
# Out:
# [array([ 0.94282027,  0.08404627,  0.55399828,  0.54389275,  0.08474579,
#         0.02285415,  0.07517029,  0.09562356,  0.5216207 ,  0.05991466,
#         0.30209923,  0.31473615,  0.57240088,  0.04658185,  0.35675423,
#         0.35915212,  0.94086814,  0.1144508 ,  0.57304342,  0.5361992 ,
#         0.09017375,  0.01319472,  0.08114911,  0.08389354,  0.53675188,
#         0.05161463,  0.30371611,  0.31826361,  0.54734847,  0.06628918,
#         0.28076847,  0.29305275]), array([ 0.92178124,  0.09007299,  0.54783593,  0.51239625,  0.08059282,
#         0.01438022,  0.09119592,  0.08419842,  0.51588189,  0.05088013,
#         0.29061782,  0.33097881,  0.52788254,  0.06759221,  0.29503946,
#         0.27589806,  0.94678545,  0.09719855,  0.55044643,  0.54676191,
#         0.08976429,  0.01610185,  0.08334235,  0.0940526 ,  0.51507292,
#         0.05875739,  0.299535  ,  0.29362203,  0.52383783,  0.05742773,
# ...
